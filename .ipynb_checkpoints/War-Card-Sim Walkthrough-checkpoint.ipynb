# %%
# %matplotlib inline

import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %% [markdown]
# # War-Card-Sim Walkthrough
#
# Author: Michael Skrzypiec @skrzym
#
# ## Purpose:
#
# This notebook is a walkthrough of a simple python based simulation of the card game 'War'.
#
# This simulation and walkthrough is a learning project for me to:
# * Work with python some more
# * Test some basic python analytics and graphing packages
# * Use Jupyter/IPython notebooks
# * Keep everything organized with git and publishing on github.
# * Show how random the game of 'War' is if you didn't already know...
#
# ## How to Play War
# Placeholder...
#
# ## 10,000 Games Of War
# What can we learn from simulating so many games of war? Well lets take a look.
#
# First lets set up and run our simulation for 2 players to play 10,000 games of war.

# %%
import war_sim
sim_one = war_sim.Simulation(num_games=2000, num_players=2)
sim_one.run_simulation()
# Out:
# Game 2000 of 2000
# War Cards:	3
# P1 Wins:	1038
# P2 Wins:	962
# Avg Len:	230.86
# Avg WDif:	13.017
# Avg Wars:	28.996
# Sum Wars:	57992
# Annom Rate:	0.0555

# %% [markdown]
# So after the simulation finishes we get some basic stats about our 10,000 games.
# * War Cards - Number of cards each play at war puts face down on the table before revealing their new battle card.
# * P1/P2 Wins - Number of wins each player had.
# * Avg Len - How many steps it took on average to complete one game.
# * Avg WDiff - How many wins typically separated the winner from the loser of a game.
# * Avg Wars - On average how many wars happend during the course of one game.
# * Sum Wars - How many wars took place in total.
# * Annom Rate - The percent of games where the winner did not also win the most number of wars

# %% [markdown]
# ## So now what?
# Well ... these stats are just some calculations done on lists of data gathered by the simulation. Lets see if we can explore those lists a bit further.

# %%
sim_array = []
for cards in range(1,6):
    sim = war_sim.Simulation(num_games=1000, num_players=2, num_war_cards=cards)
    sim.run_simulation()
    sim_array.append(sim)
# Out:
# Game 1000 of 1000
# War Cards:	1
# P1 Wins:	532
# P2 Wins:	468
# Avg Len:	435.572
# Avg WDif:	18.718
# Avg Wars:	55.088
# Sum Wars:	55088
# Annom Rate:	0.165
#
# Game 1000 of 1000
# War Cards:	2
# P1 Wins:	530
# P2 Wins:	470
# Avg Len:	318.567
# Avg WDif:	15.489
# Avg Wars:	40.006
# Sum Wars:	40006
# Annom Rate:	0.098
#
# Game 1000 of 1000
# War Cards:	3
# P1 Wins:	506
# P2 Wins:	494
# Avg Len:	230.854
# Avg WDif:	12.95
# Avg Wars:	29.034
# Sum Wars:	29034
# Annom Rate:	0.058
#
# Game 1000 of 1000
# War Cards:	4
# P1 Wins:	495
# P2 Wins:	505
# Avg Len:	174.11
# Avg WDif:	11.152
# Avg Wars:	21.79
# Sum Wars:	21790
# Annom Rate:	0.055
#
# Game 1000 of 1000
# War Cards:	5
# P1 Wins:	487
# P2 Wins:	513
# Avg Len:	139.167
# Avg WDif:	9.733
# Avg Wars:	17.574
# Sum Wars:	17574
# Annom Rate:	0.026

# %%
# Put game length data into a pandas data frame
data_stack = []
label_stack = []
for sim in range(len(sim_array)):
    for value in sim_array[sim].sim_length:
        data_stack.append(value)
        label_stack.append(str(sim + 1))
data_dict = {'Number of War Cards': label_stack, 'Game Length': data_stack}
df = pd.DataFrame.from_dict(data=data_dict)

print df.head(n=5)
# Out:
#    Game Length Number of War Cards
# 0          452                   1
# 1          230                   1
# 2          328                   1
# 3          238                   1
# 4          528                   1

# %%
# Lets plot the results
sns.set(style="dark", palette="pastel", color_codes=True)
fig = plt.figure(figsize = (20,10))

ax1 = fig.add_subplot(121)
ax1.set_ylim([0,750])
ax1.yaxis.set_major_locator(ticker.MultipleLocator(50))
sns.boxplot(x='Number of War Cards', y='Game Length', data=df, ax=ax1)

ax2 = fig.add_subplot(122, sharey=ax1)
ax2.set_ylim([0,750])
ax2.yaxis.set_major_locator(ticker.MultipleLocator(50))
sns.violinplot(x='Number of War Cards', y='Game Length', data=df, ax=ax2)

# %%
# distributions
sns.set(style="white", palette="pastel", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(4, 1, figsize=(10, 8), sharex=True)
sns.despine()

# Generate a random univariate dataset
d = rs.normal(size=100)

# Plot a simple histogram with binsize determined automatically
sns.distplot(sim_array[0].sim_length, kde=False, color="b", ax=axes[0])

# Plot a kernel density estimate and rug plot
sns.distplot(sim_array[1].sim_length, hist=False, rug=True, color="r", ax=axes[1])

# Plot a filled kernel density estimate
sns.distplot(sim_array[2].sim_length, hist=False, color="g", kde_kws={"shade": True}, ax=axes[2])

# Plot a historgram and kernel density estimate
sns.distplot(sim_array[3].sim_length, color="m", ax=axes[3])

plt.setp(axes, yticks=[])
plt.tight_layout()
